# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !scp '/content/gdrive/My Drive/datta.zip' '/content/datta.zip'


# !unzip '/content/datta.zip' -d '/content/'
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: /content/datta/train/pollution/45a11147.jpg
#   inflating: /content/datta/train/pollution/45a3a6e3.jpg
#   inflating: /content/datta/train/pollution/45a70c4e.jpg
#   inflating: /content/datta/train/pollution/45af3713.jpg
#   inflating: /content/datta/train/pollution/45b20c7b.jpg
#   inflating: /content/datta/train/pollution/45b666be.jpg
#   inflating: /content/datta/train/pollution/45b76626.jpg
#   inflating: /content/datta/train/pollution/45c474e1.jpg
#   inflating: /content/datta/train/pollution/45e4f5ec.jpg
#   inflating: /content/datta/train/pollution/45eab0ab.jpg
#   inflating: /content/datta/train/pollution/45ef9380.jpg
#   inflating: /content/datta/train/pollution/45eff481.jpg
#   inflating: /content/datta/train/pollution/45f052bb.jpg
#   inflating: /content/datta/train/pollution/460e7ae0.jpg
#   inflating: /content/datta/train/pollution/4625caa8.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.3/716.3 kB 14.2 MB/s eta 0:00:00
# ...

# %%
import os

from ultralytics import YOLO


# Load a model
model = YOLO("yolov8n-cls.pt")  # load a pretained model

# Use the model
results = model.train(data='/content/datta/', epochs=6)  # train the model
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from ultralytics import YOLO
import numpy as np
# Load the trained image classification model
model = YOLO('runs/classify/train2/weights/best.pt')

# %%
results = model('1.PNG')
# Out:
# image 1/1 /content/1.PNG: 224x224 pollution 1.00, clean 0.00, 27.4ms
# Speed: 13.3ms preprocess, 27.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model('2.PNG')
# Out:
# image 1/1 /content/2.PNG: 224x224 clean 1.00, pollution 0.00, 28.7ms
# Speed: 7.1ms preprocess, 28.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
results = model('3.jpg')
# Out:
# image 1/1 /content/3.jpg: 224x224 pollution 1.00, clean 0.00, 24.2ms
# Speed: 9.6ms preprocess, 24.2ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/pollution'
